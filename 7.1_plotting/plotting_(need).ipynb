# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Plotting (Need)</span></div>

# %%
#quick to plot & useful for analysing data, use plt
#but to generate nice plot for presentation, use other plotting methods

# %%
from matplotlib import pyplot as plt
import numpy as np

# %% [markdown]
# # What to expect in this chapter

# %% [markdown]
# # 1 A simple plot

# %% [markdown]
# ## 1.1 Let’s look at some code.

# %%
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]

# Let's start plotting
plt.plot(x, y_1, label='Y values',
         color='red', linestyle='dashed')
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25) #alpha controls the transparancy of the grid, it takes a value between 0 and 1
#have a low opacity of the grid to highlight the data
plt.legend(loc='lower left') #upper left / lower left


# plt.clf() to clear the figure

# %% [markdown]
# ### Things to note

# %%
#short forms
# color -> c
# linestyle -> ls
# linewidth -> lw
# include plt.show() to show the figure

# %%
#default values for parameters
plt.plot(x, y_1, y_2)
# Out:
# [<matplotlib.lines.Line2D at 0x1e8da212360>,
#  <matplotlib.lines.Line2D at 0x1e8da212270>]

# %%
plt.plot(x, y_1, color='red', linestyle='dashed', linewidth=2)

# %%
plt.plot(x, y_1, label='Y values',
           color='red', linestyle='dashed')

# %% [markdown]
# ## 1.2 Adding another plot

# %%
plt.plot(x, y_2,
         label='Y2 values', color='blue')

# %%
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]

# Lets start plotting
plt.plot(x, y_1, label='Y1 values', color='red', linestyle='dashed')
plt.plot(x, y_2, label='Y2 values', color='blue')
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25)
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ## 1.3 Yet another plot but with error bars

# %%
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]
y_3 = [0, 4, 8, 12, 16, 20, 24]
x_error, y_error = .1, 0.75

# Lets start plotting
plt.plot(x, y_1, label='Y1 values', color='red', linestyle='dashed',)
plt.plot(x, y_2, label='Y2 values', color='blue', )
plt.errorbar(x, y_3, xerr=x_error, yerr=y_error,
             label='Y3 with errors', color='green')
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25)
plt.legend(loc='upper left')

# %% [markdown]
# # 2 Better with NumPy

# %%
x = np.linspace(0,6) 
#generate 50 vlueas from 0 to 6, evenly spaced 

x2 = x**2
#short form for a black dotted line 
#plt.plot(x, x**2, ,'k--')
# Out:
# array([0.        , 0.12244898, 0.24489796, 0.36734694, 0.48979592,
#        0.6122449 , 0.73469388, 0.85714286, 0.97959184, 1.10204082,
#        1.2244898 , 1.34693878, 1.46938776, 1.59183673, 1.71428571,
#        1.83673469, 1.95918367, 2.08163265, 2.20408163, 2.32653061,
#        2.44897959, 2.57142857, 2.69387755, 2.81632653, 2.93877551,
#        3.06122449, 3.18367347, 3.30612245, 3.42857143, 3.55102041,
#        3.67346939, 3.79591837, 3.91836735, 4.04081633, 4.16326531,
#        4.28571429, 4.40816327, 4.53061224, 4.65306122, 4.7755102 ,
#        4.89795918, 5.02040816, 5.14285714, 5.26530612, 5.3877551 ,
#        5.51020408, 5.63265306, 5.75510204, 5.87755102, 6.        ])

# %%
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]

np_x = np.array(x)
np_y_1 = np.array(y_1)
np_y_2 = np.array(y_2)

plt.plot(np_x, np_y_1, color='red', linestyle='dashed', label='Y values')
plt.plot(np_x, np_y_2, color='blue', label='Y2 values')

# %% [markdown]
# ## 2.1 Adding mathematical functions

# %%
x = np.array([0, 1, 2, 3, 4, 5, 6])

x2 = x**2                  # The math stuff
sin_x = np.sin(x)

plt.plot(x, x2, label='x^2',
         color='red', linestyle='dashed', )
plt.plot(x, sin_x, label='sin(x)',
         color='blue')
plt.legend()

# %% [markdown]
# ## We need another axis!

# %% [markdown]
# ### Things to note

# %%
x = np.array([0, 1, 2, 3, 4, 5, 6])
x2 = x**2
sin_x = np.sin(x)

plt.plot(x, x2, label='x^2',color='red', linestyle='dashed')
plt.legend(loc='lower left')                                  # For y-axis 1

plt.twinx()                                                   # This creates a new y-axis 
                                                              # for the plots that comes after
plt.plot(x, sin_x, label='sin(x)',color='blue', )
plt.legend(loc='lower right')                                 # For y-axis 2

# %%
x = np.linspace(0, 6, 100) #improvement
x2 = x**2
sin_x = np.sin(x)

plt.plot(x, x2, label='x^2',color='red', linestyle='dashed')
plt.legend(loc='lower left')                                  # For y-axis 1

plt.twinx()                                                   # This creates a new y-axis 
                                                              # for the plots that comes after
plt.plot(x, sin_x, label='sin(x)',color='blue', )
plt.legend(loc='lower right')                                 # For y-axis 2

# %% [markdown]
# # 3 Saving to disc

# %%
# plt.savefig('hahaha.png', dpi = 150) 
# plt.savefig('hahaha.jpg', dpi = 150)
# plt.savefig('hahaha.pdf', dpi = 150) -> dpi = dots per inch 
# difference: size of file, png can have clear background whereas jpg cannot, jpg files are smaller cos they are compact  
# different format
# choose the right type of files in the report

# %%
# When you run this code, you will find the file saved in the same directory (folder) as the one in your notebook lives in. 
# If you want it saved elsewhere, specify the path in more detail.
# e.g. plt.savefig('C://Desktop/simple-plot.png', dpi=150)

# %% [markdown]
# # 4 A real example: Global Warming

# %% [markdown]
# ## 4.1 Plotting data from files

# %%
file_url = 'https://berkeley-earth-temperature.s3.us-west-1.amazonaws.com/Global/Raw_TAVG_complete.txt'
data = np.loadtxt(file_url, skiprows = 47)
date = data[:, 0]
anomaly = data[:, -1]

plt.plot(date, anomaly, alpha=.5)
plt.ylim([-8, 8])
plt.hlines(0, date[0], date[-1], linestyle='--', colors='grey')

#can plot scatter data as well

# %%
years = data[:,1]
anomaly = data[:,-1]
plt.scatter(years, anomaly, alpha = .15, s = .1)

year_min, year_max = years.min(), years.max()
plt.hlines(0, year_min, year_max, color='r', linestyle='--', alpha=.5)

# %% [markdown]
# ## 4.2 Styles

# %%
plt.style.use('fivethirtyeight')
# plt.style.use('ggplot')
# plt.style.use('bmh')
# plt.style.use('grayscale')
# https://matplotlib.org/stable/gallery/style_sheets/style_sheets_reference.html
# useful website for scieniceplots: https://github.com/garrettj403/SciencePlots

# %% [markdown]
# ### xkcd!

# %%
# plt.xkcd()

# %% [markdown]
# ### Resetting styles

# %%
# plt.style.use('default')
