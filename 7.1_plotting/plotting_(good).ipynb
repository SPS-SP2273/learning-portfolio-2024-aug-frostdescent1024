# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Plotting (Good)</span></div>

# %%
from matplotlib import pyplot as plt
import numpy as np

# %% [markdown]
# # What to expect in this chapter

# %% [markdown]
# # 1 Some nomenclature

# %% [markdown]
# # 2 Comparing the two ‘dialects’

# %% [markdown]
# ### pyplot Interface

# %%
x = np.linspace(-np.pi, np.pi, num=100)
cos_x = np.cos(x)
sin_x = np.sin(x)

# %%
# if use math.sin(x), there will be TypeError

# %%
plt.plot(x, cos_x, label='cos x')
plt.plot(x, sin_x, label='sin x')
plt.legend()
#ax.legend()

# %%
fig, ax = plt.subplots(ncols=3, nrows=2, figsize=(10,3), sharex='col', sharey='row')

for count, a in enumerate(ax.flatten()):
    if count == 3:
        a.plot(x, 10*cos_x, 'r')
        continue
    
#for a in ax.flatten():
    a.plot(x, sin_x)
    a.grid(alpha=.25)
    # a.spines['right'].set_variable(False)
    # a.spines['left'].set_variable(False)
    # a.spines['top'].set_variable(False)

plt.tight_layout()
# ax[0,1].plot(x, sin_x)
# ax[0,2].plot(x, sin_x)
# ax[1,0].plot(x, sin_x)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 11
#       9 a.plot(x, sin_x)
#      10 a.grid(alpha=.25)
# ---> 11 a.spines['right'].set_variable(False)
#      12 a.spines['left'].set_variable(False)
#      13 a.spines['top'].set_variable(False)
#
# AttributeError: 'Spine' object has no attribute 'set_variable'

# %% [markdown]
# ### OO Interface

# %%
fig, ax = plt.subplots(nrows=1, ncols=2)  

ax[0].plot(x, cos_x, label='cos x')
ax[1].plot(x, sin_x, label='sin x')

# %%
type(ax)
# Out:
# numpy.ndarray

# %%
ax.shape
# Out:
# (2, 2)

# %%
type(ax[0])
# Out:
# numpy.ndarray

# %% [markdown]
# # 3 What is OO ax, really?

# %%
fig, ax = plt.subplots(ncols=20, nrows=1)

# %%
fig, ax = plt.subplots(ncols=1, nrows=20)

# %% [markdown]
# # 4 A complete OO example

# %%
fig, ax = plt.subplots(nrows=2, ncols=1,
                       figsize=(5, 5), #adjust figure size
                       sharex=True) # let all the lots share the x-axis
# Since ax is a NumPy array with two axes, we can index them using 0 and 1
ax[0].plot(x, cos_x, label=r'$\cos(x)$') 
ax[0].fill_between(x, 0, cos_x, alpha=.25)
ax[1].plot(x, sin_x, label=r'$\sin(x)$')
ax[1].fill_between(x, 0, sin_x, alpha=.25)

# for all the sub-plots
for a in ax:
    a.legend()
    a.grid(alpha=.25)
    a.set_ylabel('$y$', rotation=0)

ax[1].set_xlabel('$x$')

#super title to the figure
fig.suptitle(r'$\sin(x)$ and $\cos(x)$')
fig.tight_layout()

# %% [markdown]
# # 5 Multiple rows and columns

# %%
fig, ax = plt.subplots(nrows=2, ncols=2,
                       figsize=(5, 5),
                       sharex='col', sharey='col')

# Some variables to access the axes and improve readabilty
# top_left, top_right, bottom_left, bottom_right = ax.flatten()
[[top_left, top_right], [bottom_left, bottom_right]] = ax

top_left.set_title('Top Left')
top_right.set_title('Top Right')
bottom_left.set_title('Bottom Left')
bottom_right.set_title('Bottom Right')

top_left.hlines(y=1, xmin=0, xmax=4)
top_right.hlines(y=2, xmin=0, xmax=5)
bottom_left.bar(range(x))
bottom_right.hlines(y=4, xmin=0, xmax=5)

x = np.array(10)


for a in ax.flatten():
    a.grid(alpha=.25)

plt.tight_layout()

# %% [markdown]
# ### Using ax

# %%
# Your code here

# %% [markdown]
# ## 5.1 Sharing axes

# %% [markdown]
# ## 5.2 Accessing all axes

# %% [markdown]
# # 6 Other useful plots

# %% [markdown]
# ## 6.1 Histograms

# %% [markdown]
# ### Data

# %%
# Your code here

# %% [markdown]
# ### A quick helper function

# %%
# Your code here

# %% [markdown]
# ### The histogram

# %%
# Your code here

# %% [markdown]
# ## 6.2 Scatter plots

# %% [markdown]
# ## 6.3 Bar charts

# %% [markdown]
# ## 6.4 Pie charts

# %%
student_numbers = {'Life Sciences': 14,
                   'Physics': 12,
                   'Chemistry': 8,
                   'Comp. Biology': 1}
majors = list(student_numbers.keys())
numbers = list(student_numbers.values())

plt.style.use('fivethirtyeight')
plt.pie(numbers, 
        labels=majors,
        autopct='%1.1f%%',   # How to format the percentages
        startangle=-90                
        )
plt.title('Percentage of each major')
# Out:
# Text(0.5, 1.0, 'Percentage of each major')
